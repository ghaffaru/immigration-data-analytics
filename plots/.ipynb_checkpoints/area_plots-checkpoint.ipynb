# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %%
df_can = pd.read_excel('../data/Canada.xlsx', sheet_name="Canada by Citizenship", skiprows=range(20), skipfooter=2)

# %%
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent','RegName':'Region'}, inplace=True)

# let's view the first five elements and see how the dataframe was changed
df_can.head()
# Out:
#          Type    Coverage         Country  AREA Continent   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935      Asia  5501
# 1  Immigrants  Foreigners         Albania   908    Europe   925
# 2  Immigrants  Foreigners         Algeria   903    Africa   912
# 3  Immigrants  Foreigners  American Samoa   909   Oceania   957
# 4  Immigrants  Foreigners         Andorra   908    Europe   925
#
#             Region  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
# examine the types of the column labels
all(isinstance(column, str) for column in df_can.columns)
# Out:
# False

# %%
# change to strings
df_can.columns = list(map(str, df_can.columns))
all(isinstance(column, str) for column in df_can.columns)
# Out:
# True

# %%
df_can.set_index('Country', inplace=True)
df_can.head()
# Out:
#                       Type    Coverage  AREA Continent   REG           Region  \
# Country
# Afghanistan     Immigrants  Foreigners   935      Asia  5501    Southern Asia
# Albania         Immigrants  Foreigners   908    Europe   925  Southern Europe
# Algeria         Immigrants  Foreigners   903    Africa   912  Northern Africa
# American Samoa  Immigrants  Foreigners   909   Oceania   957        Polynesia
# Andorra         Immigrants  Foreigners   908    Europe   925  Southern Europe
#
#                 DEV             DevName  1980  1981  ...  2004  2005  2006  \
# Country                                              ...
# Afghanistan     902  Developing regions    16    39  ...  2978  3436  3009
# Albania         901   Developed regions     1     0  ...  1450  1223   856
# Algeria         902  Developing regions    80    67  ...  3616  3626  4807
# American Samoa  902  Developing regions     0     1  ...     0     0     1
# ...

# %%
# add total column
df_can['Total'] = df_can.sum(axis=1)

# %%
# finally, let's create a list of years from 1980 - 2013
# this will come in handy when we start plotting the data
years = list(map(str, range(1980, 2014)))

years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
# use the inline backend to generate the plots within the browser
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  2.2.4

# %%
# area plot of top 5 countries with high immigration
df_can.sort_values(by="Total", ascending=False, axis=0, inplace=True)
df_top5 = df_can.head()[years].transpose()

# %%
df_top5
# Out:
# Country  India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980      8880   5123                                              22045
# 1981      8670   6682                                              24796
# 1982      8147   3308                                              20620
# 1983      7338   1863                                              10015
# 1984      5704   1527                                              10170
# 1985      4211   1816                                               9564
# 1986      7150   1960                                               9470
# 1987     10189   2643                                              21337
# 1988     11522   2758                                              27359
# 1989     10343   4323                                              23795
# 1990     12041   8076                                              31668
# 1991     13734  14255                                              23380
# ...

# %%
# change the index values to type int for ploting
df_top5.index = df_top5.index.map(int)
df_top5.plot(kind='area', stacked=False, figsize=(20,10))
plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
plt.savefig('../fig_outputs/top_5_area_plot.jpg')
plt.show()

# %%
df_least5 = df_can.sort_values(by="Total", ascending=True, axis=0).tail()
df_least5
# Out:
#                                                           Type    Coverage  \
# Country
# Pakistan                                            Immigrants  Foreigners
# Philippines                                         Immigrants  Foreigners
# United Kingdom of Great Britain and Northern Ir...  Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# India                                               Immigrants  Foreigners
#
#                                                     AREA Continent   REG  \
# Country
# Pakistan                                             935      Asia  5501
# Philippines                                          935      Asia   920
# United Kingdom of Great Britain and Northern Ir...   908    Europe   924
# China                                                935      Asia   906
# India                                                935      Asia  5501
#
# ...

# %%
### least 5 countries with contributions
# df_least5 = df_can.tail(5)

df_least5 = df_least5[years].transpose()
df_least5.head()

df_least5.index = df_least5.index.map(int)
ax = df_least5.plot(kind='area', alpha=0.55, stacked=False, figsize=(20,10))

ax.set_label('Immigration Trend of 5 Countries with Least Contribution to Immigration')
ax.set_ylabel('Number of immigrants')
ax.set_xlabel('Years')
plt.savefig('../fig_outputs/last_5_countries.jpg')
